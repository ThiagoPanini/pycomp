# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Leitura-dos-Dados" data-toc-modified-id="Leitura-dos-Dados-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Leitura dos Dados</a></span></li><li><span><a href="#EDA:-Explorando-Insights" data-toc-modified-id="EDA:-Explorando-Insights-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA: Explorando Insights</a></span><ul class="toc-item"><li><span><a href="#Taxa-de-Sobrevivência" data-toc-modified-id="Taxa-de-Sobrevivência-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Taxa de Sobrevivência</a></span></li><li><span><a href="#Análise-de-Gênero" data-toc-modified-id="Análise-de-Gênero-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Análise de Gênero</a></span></li><li><span><a href="#A-Influência-da-Classe-Social" data-toc-modified-id="A-Influência-da-Classe-Social-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>A Influência da Classe Social</a></span></li><li><span><a href="#A-Presença-de-Acompanhantes" data-toc-modified-id="A-Presença-de-Acompanhantes-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>A Presença de Acompanhantes</a></span></li><li><span><a href="#O-Fator-Idade" data-toc-modified-id="O-Fator-Idade-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>O Fator Idade</a></span></li><li><span><a href="#O-Valor-de-Ticket-Pago" data-toc-modified-id="O-Valor-de-Ticket-Pago-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>O Valor de Ticket Pago</a></span></li><li><span><a href="#Análises-Conjuntas" data-toc-modified-id="Análises-Conjuntas-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Análises Conjuntas</a></span></li></ul></li><li><span><a href="#Prep:-Construção-de-Pipelines" data-toc-modified-id="Prep:-Construção-de-Pipelines-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Prep: Construção de Pipelines</a></span><ul class="toc-item"><li><span><a href="#Pipeline-Inicial" data-toc-modified-id="Pipeline-Inicial-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Pipeline Inicial</a></span><ul class="toc-item"><li><span><a href="#Features-Customizadas" data-toc-modified-id="Features-Customizadas-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Features Customizadas</a></span></li><li><span><a href="#Features-Candidatas" data-toc-modified-id="Features-Candidatas-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Features Candidatas</a></span></li><li><span><a href="#Dados-Duplicados" data-toc-modified-id="Dados-Duplicados-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Dados Duplicados</a></span></li><li><span><a href="#Alterando-Tipos-Primitivos" data-toc-modified-id="Alterando-Tipos-Primitivos-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Alterando Tipos Primitivos</a></span></li><li><span><a href="#Dados-de-Treino-e-de-Validação" data-toc-modified-id="Dados-de-Treino-e-de-Validação-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Dados de Treino e de Validação</a></span></li></ul></li><li><span><a href="#Pipeline-Numérico" data-toc-modified-id="Pipeline-Numérico-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Pipeline Numérico</a></span><ul class="toc-item"><li><span><a href="#Dados-Nulos" data-toc-modified-id="Dados-Nulos-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Dados Nulos</a></span></li><li><span><a href="#Transformação-Logaritma" data-toc-modified-id="Transformação-Logaritma-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Transformação Logaritma</a></span></li><li><span><a href="#Normalização" data-toc-modified-id="Normalização-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Normalização</a></span></li></ul></li><li><span><a href="#Pipeline-Categórico" data-toc-modified-id="Pipeline-Categórico-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Pipeline Categórico</a></span><ul class="toc-item"><li><span><a href="#Encoding" data-toc-modified-id="Encoding-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Encoding</a></span></li></ul></li><li><span><a href="#Pipelines-Completos" data-toc-modified-id="Pipelines-Completos-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Pipelines Completos</a></span></li></ul></li><li><span><a href="#Modelagem:-Prevendo-Sobrevivência" data-toc-modified-id="Modelagem:-Prevendo-Sobrevivência-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Modelagem: Prevendo Sobrevivência</a></span><ul class="toc-item"><li><span><a href="#Definições-Iniciais" data-toc-modified-id="Definições-Iniciais-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Definições Iniciais</a></span></li><li><span><a href="#Treinamento-de-Modelos" data-toc-modified-id="Treinamento-de-Modelos-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Treinamento de Modelos</a></span></li><li><span><a href="#Avaliando-Performance" data-toc-modified-id="Avaliando-Performance-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Avaliando Performance</a></span></li><li><span><a href="#Fluxo-de-Treino-e-Avaliação" data-toc-modified-id="Fluxo-de-Treino-e-Avaliação-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Fluxo de Treino e Avaliação</a></span></li></ul></li><li><span><a href="#Tunagem-de-Hyperparâmetros" data-toc-modified-id="Tunagem-de-Hyperparâmetros-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Tunagem de Hyperparâmetros</a></span></li><li><span><a href="#Teste:-Validação-Final" data-toc-modified-id="Teste:-Validação-Final-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Teste: Validação Final</a></span></li></ul></div>

# %% [markdown]
# Este notebook tem por objetivo alocar o desenvolvimento referente a análise exploratória de insights relacionada ao dataset [Titanic - Machine Learning from Disaster](https://www.kaggle.com/c/titanic) retirado da plataforma Kaggle para aprimoramento de skills em Data Science e Machine Learning.
#
# ___
# **_Descrição e contexto:_**
# _O naufrágio do navio Titanic é um dos eventos mais conhecidos em todo o mundo. [...]Enquanto alguns fatores relacionados a "sorte" se fizeram presentes entre os sobreviventes, aparentemente alguns grupos específicos de passageiros e tripulantes possuíram maiores probabilidades de sobrevivência que outros. Neste desafio, é proposta a criação de um modelo de Machine Learning capaz de responder a seguinte questão: "Quais grupos de pessoas poderiam ter mais condição de sobreviver ao naufrágio?"_

# %% [markdown]
#     !pip install pycomp --upgrade --no-cache-dir

# %%
# Bibliotecas do projeto
import pandas as pd
import os
from warnings import filterwarnings
filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# Variáveis do projeto
DATA_PATH = 'data/'
TRAIN_FILENAME = 'train.csv'
TEST_FILENAME = 'test.csv'

# %% [markdown]
# # Leitura dos Dados

# %% [markdown]
# Após a importação das principais bibliotecas comuns ao projeto e também da definição de variávies importantes para a leitura dos dados, é possível realizar o primeiro contato com a base de dados disponível para o desenvolvimento da tarefa.

# %%
# Lendo dados de treino
df = pd.read_csv(os.path.join(DATA_PATH, TRAIN_FILENAME))
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Uma vez lida a base de treino, é possível analisar os atributos contidos na mesma a partir de seus [metadados](https://www.kaggle.com/c/titanic/data):
#
# - **_PassengerId_:** id do passageiro ou tripulante do navio;
# - **_Survived_:** variável resposta indicando a sobrevivência do passageiro ou tripulante;
# - **_Pclass_:** categoria indicativa da classe do ticket do passageiro (1=alta, 2=média ou 3=baixa);
# - **_Name_:** nome do passageiro ou tripulante;
# - **_Sex_:** gênero do passageiro ou tripulante;
# - **_Age_:** idade do passageiro ou tripulante;
# - **_SibSp_:** quantidade de irmãos ou cônjuges presentes na embarcação;
# - **_Parch_:** quantidade de pais ou filhos presentes na embarcação;
# - **_Ticket_:** número referente ao ticket do passageiro ou tripulante;
# - **_Fare_:** valor da tarifa paga pelo passageiro ou tripulante;
# - **_Cabin_:** número da cabine do passageiro ou tripulante;
# - **_Embarked_:** porto de embarque do passageiro ou tripulante (C=Cherbourg, Q=Queenstown, S=Southampton).

# %% [markdown]
# # EDA: Explorando Insights

# %% [markdown]
# Neste ponto, tem-se um contexto bem definido do objetivo do projeto, além de uma base de dados já lida e transformada em um formato DataFrame do pandas. A partir deste momento, será proposta uma verdadeira varredura nos dados para a aplicação de uma análise descritiva detalhada em prol do levantamento de insights relevantes para o contexto de negócio.
#
# Utilizando o pacote caseiro [pycomp](https://github.com/ThiagoPanini/pycomp), cuja construção foi motivada exatamente para facilitar o trabalho de cientistas de dados nos pilares de insights, prep e modelagem, espera-se, dessa segunda sessão, um entendimento pleno sobre o conjunto de dados disponíveis e uma ideia clara sobre os passos necessários para serem aplicados no prep e na modelagem.

# %% [markdown]
# <img src="https://i.imgur.com/WcAaq1P.png" alt="pycomp Logo"></a>

# %% [markdown]
# ## Taxa de Sobrevivência

# %%
# Importando bibliotecas
from pycomp.viz.insights import *

# Taxa de sobrevivência
survived_map = {1: 'Sobreviventes', 0: 'Vítimas'}
survived_colors = ['crimson', 'darkslateblue']
plot_donut_chart(df=df, col='Survived', label_names=survived_map, colors=survived_colors,
                 title='Volume e percentual de passageiros sobreviventes \nao naufrágio do Titanic')

# %% [markdown]
# O gráfico acima mostra claramente a proporção de sobreviventes e vítimas dos 891 passageiros e tripulantes presentes na base de dados disponível para análise. Nele, é possível perceber um maior número de vítimas do naufrágio, totalizando 549 passageiros ou 61.6% do total. A parcela de sobreviventes, em menor número, soma 342 passageiros ou 38.4% do total.
#
# A variável `Survived` pode ser dada como a variávle _target_ de um possível modelo preditivo a ser treinado futureamente neste notebook. O grande objetivo é analisar os principais fatores ou identificar os principais grupos de passageiros com maior chance de sobrevivência frente as características demográficas e sociais presentes na base.

# %% [markdown]
# ## Análise de Gênero

# %% [markdown]
# A partir da análise de sobrevivência realizada acima, é possível expandir as visões utilizando outras variáveis presentes na base. Nesta sessão, vamos verificar se existiu alguma influência do gênero dos passageiros na questão da sobrevivência.

# %%
# Contagem de passageiros por gênero
gender_colors = ['lightskyblue', 'lightcoral']
gender_map = {'male': 'Masculino', 'female': 'Feminino'}
plot_countplot(df=df, col='Sex', palette=gender_colors, label_names=gender_map,
               title='Quantidade total de passageiros por gênero')

# %% [markdown]
# Pelo gráfico acima, percebe-se que o público de viajantes do Titanic era formado por aproximadamente 65% homens e 35% mulheres, e isso provavelmente pode ser considerado um cenário padrão para a época (afinal, estamos falando de algo ocorrido em meados de 1911).
#
# Ter em mente a volumetria total por gênero é essencial para uma análise posterior de taxa de sobrevivência por gênero.

# %%
# Sobrevivência por gênero
plot_countplot(df=df, col='Survived', hue='Sex', label_names=survived_map, palette=gender_colors,
               title="O gênero do passageiro poderia ter influenciado \nna chance de sobrevivência?")

# %% [markdown]
# O gráfico acima mostra que, das 549 vítimas registradas (61.6% do total), temos 468 (ou 52.5%) do gênero masculino e apenas 81 (ou 9.1%) do gênero feminino. Por outro lado, da parcela de 342 (ou 38.4%) de sobreviventes, temos 109 (ou 12.2%) do gênero masculino e 233 (ou 26.2%) do gênero feminino.
#
# Em outras palavras, o gráfico nos mostra que houve uma possível prioridade de resgate dada às mulheres da embarcação, visto que sua parcela de representatividade é mais significante no grupo dos sobreviventes do que no grupo das vítimas. Para explicar este cenário, é possível imaginar a existência de um possível protocolo de resgate para priorização de mulheres e crianças em casos de emergência.
#
# Uma outra forma de analisar essa representatividade de sobrevivência por gênero pode ser dada pelo gráfico duplo de rosca abaixo:

# %%
# Plotting a double donut chart
plot_double_donut_chart(df=df, col1='Survived', col2='Sex', label_names_col1=survived_map, 
                        colors1=['crimson', 'navy'], colors2=['lightcoral', 'lightskyblue'],
                        title="O gênero do passageiro poderia ter influenciado \nna chance de sobrevivência?")

# %% [markdown]
# Ambos os gráficos comprovam: passageiras do gênero feminino tiveram prioridade no resgate durante o naufrágio.

# %% [markdown]
# ## A Influência da Classe Social

# %% [markdown]
# O próximo tópico de análise leva em consideração os valores contidos na variável `Pclass` que, por sua vez, traz consigo uma informação referente a classe social de cada um dos passageiros presentes na embarcação.

# %%
# Passageiros por classe social
pclass_map = {1: 'Classe Alta', 2: 'Classe Média', 3: 'Classe Baixa'}
plot_pie_chart(df=df, col='Pclass', colors=['brown', 'gold', 'darkgrey'],
               explode=(0.03, 0, 0), label_names=pclass_map,
               title="Volumetria de passageiros do navio\npor classe social")

# %% [markdown]
# Com o gráfico de pizza acima, é possível perceber que a maioria dos passageiros e tripulantes do navio era formada por integrantes da classe baixa, representanto pouco mais de 55% do total presente. A seguir, vamos analisar se essa variável poderia, de alguma forma, ter incluenciado na sobrevivência dos passageiros

# %%
# Relação entre sobrevivência e classe social
plot_countplot(df=df, col='Pclass', hue='Survived', label_names=pclass_map, palette=survived_colors,
               title="Taxa de sobrevivência de passageiros \npor classe social")

# %% [markdown]
# A partir da leitura do gráfico de barras acima, é possível perceber como as barras vermelhas (vítimas) e azuis (sobreviventes) possuem diferentes proporções para cada uma das classes sociais analisadas na base. Em geral, temos:
#
# * Classe Alta: tem-se um número mais elevado de sobreviventes do que vítimas;
# * Classe Média: um balanço mais equalitário de sobreviventes e vítimas;
# * Classe Baixa: formada majoritariamente por vítimas.
#
# Este cenário indica uma situação clara: integrantes da dita "Classe Alta" tiveram uma maior chance de sobrevivência ao naufrágio do que, por exemplo, integrantes da "Classe Baixa". Provavelmente algum privilégio foi dado a estes passageiros durante o resgate ou, de alguma forma, estes mesmos passageiros poderiam estar alocados em posições de maior conforto/segurança no navio, facilitando assim o resgate.

# %% [markdown]
# Uma outra forma de analisar essa representatividade de sobrevivência por classe social pode ser dada a partir do gráfico de barras agrupadas abaixo:

# %%
plot_pct_countplot(df=df, col='Pclass', hue='Survived', palette='rainbow_r',
                   title='Influência da classe social na taxa de sobrevivência \ndos passageiros e tripulantes do navio')

# %% [markdown]
# ## A Presença de Acompanhantes

# %% [markdown]
# Existem duas variáveis no dataset que informam a presença de acompanhantes do passageiro na embarcação, sendo elas **SibSp** (quantidade de irmãos ou cônjuges) e **Parch** (quantidade de pais ou filhos). Nestas sessão, iremos analisar se, de alguma forma, a presença de acompanhantes influenciou na sobrevivência desses passageiros.

# %%
# Relação entre sobrevivência e a presença de companhia no navio
plot_countplot(df=df, col='SibSp', hue='Survived', orient='v', palette=survived_colors,
               title='Volumetria de sobreviventes e vítimas pela presença \nde irmãos ou cônjuges na embarcação')

# %%
# Relação entre sobrevivência e a presença de companhia no navio
plot_countplot(df=df, col='Parch', hue='Survived', orient='v', palette=survived_colors,
               title='Volumetria de sobreviventes e vítimas pela presença \nde pais ou filhos na embarcação')

# %% [markdown]
# Analisando os dois gráficos de barras acima, é possível inferir que passageiros acompanhados de 1 ou 2 pessoas, sejam estes irmãos, cônjuges, pais ou filhos, obviteram um cenário mais positivo de sobrevivência em relação aos demais.
#
# É provável que, no cenário caótico de resgate, a presença de um número não muito alto e não muito baixo de acompanhantes possa ter auxiliado no resgate em uma possível situação de ajuda mútua.

# %% [markdown]
# ## O Fator Idade

# %% [markdown]
# Bom, até este momento da análise exploratória, foram colocados em pauta apenas atributos categóricos presentes na base. Entretanto, o conjunto de dados disponível possui pelo menos duas fatures numéricas de provável importância pro objetivo do projeto: Idade e Ticket Médio.
#
# Neste primeiro momento, vamos analisar como a idade pode ter influenciado na sobrevivência dos passageiros do navio.

# %%
# Distribuição da idade dos passageiros
plot_distplot(df=df, col='Age', title="Distribuição de idade dos passageiros e tripulantes do navio")

# %% [markdown]
# Na distribuição acima, é possível ter uma ideia geral sobre o público presente no navio em termos de idade. O pico de densidade se dá aproximadamente aos 25 anos, indicando que a maior faixa de passageiros era formada por um público relativamente jovem.
#
# Vamos repetir a análise de densidade acima e construir uma curva para os sobreviventes e outra para as vítimas.

# %%
plot_distplot(df=df, col='Age', hue='Survived', kind='kde',
              title="Existe alguma relação entre a curva etária \nde sobreviventes e vítimas?")

# %% [markdown]
# No geral, o gráfico acima não mostra uma relação clara entre a influência da idade na sobrevivência dos passageiros. Entretanto, é possível destacar alguns pontos sutis do gráfico, como por exemplo, a elevação da curva em idades "próximas a 0", indicando assim uma possível prioridade de resgate dada às crianças mais novas.
#
# Este cenário também se repete, de forma mais sutil ainda, em uma parcela de passageiros acima de 80 anos.

# %% [markdown]
# ## O Valor de Ticket Pago

# %% [markdown]
# A variável `Fare` do conjunto de dados traz o valor pago por cada passageiro para ingressar ao navio Titanic. Vimos, em algumas etapas anteriores, que a classe social pode ter tido uma certa influência na chance de sobrevivência do passageiro. Este cenário se repete para o valor pago pelo ticket de entrada?

# %%
plot_distplot(df=df, col='Fare', title='Distribuição do ticket pago pelos passageiros')

# %% [markdown]
# Aqui é possível observar a distribuição do ticket pago pelos passageiros com alguns outliers do lado direito da curva (passageiros que pagaram uma quantia bem alta para o ticket de entrada)

# %%
# Distribuição de fare por classe social
plot_distplot(df=df, col='Fare', hue='Pclass', kind='strip', label_names=pclass_map,
              palette=['gold', 'silver', 'brown'],
              title="Distribuição de ticket pago por classe social")

# %% [markdown]
# O gráfico acima mostra que, em geral, quanto maior a classe social do passageiro, maior o ticket pago para ingressar ao navio. Algo esperado, mas de suma importância sua visualização gráfica nesse estudo.

# %%
plot_distplot(df=df, col='Fare', hue='Sex', kind='boxen', palette=gender_colors,
              title='Qual a distribuição de valor pago por gênero?')

# %% [markdown]
# Interessante visualizar que, em geral, as mulheres pagaram valores mais elevados que os homens.

# %%
plot_distplot(df=df, col='Fare', hue='Survived', kind='kde',
              title='Distribuição de ticket pago por sobrevivência')

# %% [markdown]
# Por fim, o gráfico acima uma distribuição de densidade relacionando o ticket médio pago por passageiro e o indicador de sobrevivência da base de dados. Aqui, é possível perceber que a curva laranja relacionada aos sobreviventes (`Survived=1`) possui uma maior concentração em altos valores para a variável `Fare`, indicando assim que o valor do ticket pode ter tido alguma influência na sobrevivência dos passageiros.

# %% [markdown]
# ## Análises Conjuntas

# %% [markdown]
# Dentro das ferramentas do módulo `insights` do pacote `pycomp`, é possível encontrar algumas funções construídas de modoa  facilitar análises em diversas colunas de uma base simultaneamente. Por exemplo, para visualizarmos volumetrias de uma série de variáveis categóricas, seria possível executar a função `plot_multiple_catplots()`, como demonstrado abaixo:

# %%
cat_cols = ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']
plot_multiple_countplots(df=df, col_list=cat_cols, orient='v')

# %% [markdown]
# Uma outra possibilidade é analisar as colunas categóricas tendo como base uma coluna numérica de agregação. Para isso, o módulo `pycomp` traz consigo a função `plot_cat_aggreg_report()`. O bloco abaixo analisa, de forma dinâmica, o comportamento da variável `Embarked` e da variável `Fare` em conjunto, respondendo perguntas como "qual a volumetria de passageiros por porto de embarque?" ou "quais as médias estatísticas de valor pago pelo ticket?"

# %%
plot_cat_aggreg_report(df=df, cat_col='Embarked', value_col='Fare', inc_x_pos=9)

# %% [markdown]
# # Prep: Construção de Pipelines

# %% [markdown]
# Após uma longa jornada na sessão de análise exploratória, reunimos valiosos insights que podem tornar o trabalho de modelagem muito mais fácil e intuitivo. Assim, os próximos tópicos desse notebook irão tratar de um passo extremamente importante para o treinamento de um modelo de machine learning: a preparação da base de dados.
#
# Para facilitar este trabalho, será utilizada uma ferramenta muito poderosa construída dentro do pacote `pycomp`. Trata-se do módulo `pycomp.ml.transformers`, sendo este composto por classes prontas capazes de realizar uma série de atividades e transformações em uma base de dados, além de uma completa integração com `Pipelines` de data prep.
#
# Antes de iniciar os passos referentes a essas transformações, vamos aplicar uma outra função igualmente poderosa do módulo `pycomp.ml.insights` capaz de retornar um overview geral de uma base de dados.

# %%
# Data overview
data_overview(df=df)
# Out:
#         feature  qtd_null  pct_null    dtype  qtd_cat
# 0         Cabin       687  0.771044   object      147
# 1           Age       177  0.198653  float64        0
# 2      Embarked         2  0.002245   object        3
# 3   PassengerId         0  0.000000    int64        0
# 4      Survived         0  0.000000    int64        0
# 5        Pclass         0  0.000000    int64        0
# 6          Name         0  0.000000   object      891
# 7           Sex         0  0.000000   object        2
# 8         SibSp         0  0.000000    int64        0
# 9         Parch         0  0.000000    int64        0
# 10       Ticket         0  0.000000   object      681
# 11         Fare         0  0.000000  float64        0

# %% [markdown]
# A função `data_overview()` retorna um DataFrame contendo informações relevantes sobre cada uma das colunas presentes em uma base de dados passada como input. O resultado acima mostra parâmetros como a quantidade de dados nulos, o tipo primitivo e a quantidade de entradas categóricas (em caso de atributos categóricos) para cada uma das colunas da base.

# %% [markdown]
# ## Pipeline Inicial

# %% [markdown]
# ### Features Customizadas

# %% [markdown]
# Nesta primeira sessão, iremos propor a construção de features customizadas na nossa base de dados, pensando numa possível extração de valor de colunas que, em seu formato bruto, provavelmente não tragam insights relevantes para um modelo preditivo. Dessa forma, os blocos de código a seguir irão focar na extração de novos insights que podem ou não serem considerados no modelo final, sendo estes:
#
# * **_name_title_**: coluna que extrai a informação do "título" do nome do passageiro (Mr, Mrs, etc)
# * **_cabin_class_**: coluna responsável por trazer a "categoria" da cabine (A, B, C, etc)
# * **_ticket_class_**: coluna que extrai informações categorizadas do ticket do passageiro
# * **_age_cat_**: coluna de categorização de faixas da variável idade
# * **_fare_cat_**: coluna de categorização de faixas da variável Fare
# * **_family_size_**: coluna para informar o tamanho total da família do passageiro
#
# Para contemplar a extração dessas novas features, será construída uma classe denominada `CustomFeaturesTitanic` que, por sua vez, contém uma inteligência de extração baseada em `RegEx` e outras regras em uma estrutura própria para inclusão dessa etapa em um possível pipeline de preparação dos dados. O grande objetivo é iterar essa e outras classes de transformação em uma busca das melhores combinações consideradas por um modelo de classificação.

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import re

class CustomFeaturesTitanic(BaseEstimator, TransformerMixin):
    
    def __init__(self, name_title=True, ticket_class=True, cabin_class=True, name_length=True,
                 age_cat=True, fare_cat=True, family_size=True, name_title_re='([a-zA-Z]+\.)', 
                 ticket_class_re='[A-Z]+([/]{0,})([^\s.]+)', cabin_class_re = '\w',
                 age_bins=[0, 10, 20, 40, 60, 999], age_labels=['0_10', '10_20', '20_40', '40_60', 'greater_60'],
                 fare_bins=[0, 8, 15, 25, 50, 99999], fare_labels=['0_8', '8_15', '15_25', '25_50', 'greater_50']):
        self.name_title = name_title
        self.ticket_class = ticket_class
        self.cabin_class = cabin_class
        self.name_length = name_length
        self.age_cat = age_cat
        self.fare_cat = fare_cat
        self.family_size = family_size
        
        self.age_bins = age_bins
        self.age_labels = age_labels
        self.fare_bins = fare_bins
        self.fare_labels = fare_labels
        self.name_title_re = name_title_re
        self.ticket_class_re = ticket_class_re
        self.cabin_class_re = cabin_class_re
        
    def fit(self, df, y=None):
        return self
    
    def transform(self, df, y=None):
        
        # Extraindo feature relacionada ao título da pessoa
        if self.name_title:
            df['name_match'] = df['Name'].apply(lambda x: re.search(self.name_title_re, x))
            df['name_regex'] = df['name_match'].apply(lambda x: ''.join(x.groups()) if x is not None else np.nan)
            
            def extract_name_title(x, other_tag='OTHER'):
                if x not in ['Mr.', 'Miss.', 'Mrs.', 'Master.']:
                    x = other_tag
                return x
                    
            df['name_title'] = df['name_regex'].apply(lambda x: extract_name_title(x))
            df.drop('name_match', axis=1, inplace=True)
            df.drop('name_regex', axis=1, inplace=True)
        
        # Extraindo feature relacionada a classe do ticket
        if self.ticket_class:
            df['ticket_match'] = df['Ticket'].apply(lambda x: re.search(self.ticket_class_re, x))
            df['ticket_regex'] = df['ticket_match'].apply(lambda x: x.group() if x is not None else 'all_numbers')
            
            # Definindo função para extração da classe
            def extract_ticket_class(x, other_tag='OTHER'):
                if x in ['A/5', 'A/4', 'A4', 'A/S']:
                    x = 'A'
                elif x in ['STON/O', 'SOTON/O', 'SOTON/OQ', 'STON/O2', 'SOTON/O2', 'SOTON']:
                    x = 'STON_SOTON'
                elif x in ['SC/PARIS', 'SC/Paris', 'SC/AH', 'SC']:
                    x = 'SC'
                elif x == 'PC':
                    x = 'PC'
                else:
                    x = other_tag
                return x

            df['ticket_class'] = df['ticket_regex'].apply(lambda x: extract_ticket_class(x))
            df.drop('ticket_match', axis=1, inplace=True)
            df.drop('ticket_regex', axis=1, inplace=True)
            
        # Extraindo feature relacionada a classe da cabine
        if self.cabin_class:
            df['cabin_match'] = df['Cabin'].apply(lambda x: re.search(self.cabin_class_re, x) if x is not np.nan else np.nan)
            df['cabin_regex'] = df['cabin_match'].apply(lambda x: x.group() if x is not np.nan else np.nan)
            
            # Definindo função para extração da classe
            def extract_cabin_class(x):
                if x in ['F', 'G', 'T']:
                    x = 'FGT'
                return x

            df['cabin_class'] = df['cabin_regex'].apply(lambda x: extract_cabin_class(x))
            df.drop('cabin_match', axis=1, inplace=True)
            df.drop('cabin_regex', axis=1, inplace=True)
            
        # Extraindo feature relacionada ao tamanho do nome
        if self.name_length:
            df['name_length'] = df['Name'].apply(lambda x: len(x))
            
        # Extraindo feature relacionada a categoria de idade
        if self.age_cat:
            df['age_cat'] = pd.cut(df['Age'], bins=self.age_bins, labels=self.age_labels)
        
        # Extraindo feature relacionada a categoria de Fare
        if self.fare_cat:
            df['fare_cat'] = pd.cut(df['Fare'], bins=self.fare_bins, labels=self.fare_labels)
            
        # Extraindo feature relacionada a tamanho da família
        if self.family_size:
            df['family_size'] = df['Parch'] + df['SibSp'] + 1
            
        return df

# %%
# Criando objeto e executando transformação
feature_adder = CustomFeaturesTitanic(name_title=True, cabin_class=True, ticket_class=True)
df_custom = feature_adder.fit_transform(df)
df_custom.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked name_title ticket_class  \
# 0      0         A/5 21171   7.2500   NaN        S        Mr.            A
# 1      0          PC 17599  71.2833   C85        C       Mrs.           PC
# 2      0  STON/O2. 3101282   7.9250   NaN        S      Miss.   STON_SOTON
# ...

# %% [markdown]
# Após a aplicação da função de transformação, seria interessante visualizar os resultados obtidos a partir das novas features criadas.

# %%
# Balanço das principais features
custom_features = ['name_title', 'ticket_class', 'cabin_class', 'age_cat', 'fare_cat', 'family_size']
plot_multiple_countplots(df=df, col_list=custom_features)

# %% [markdown]
# Após a execução do método `fit_transform()` do objeto `feature_adder`, é possível perceber, na base resultante, a presença das três novas features consideradas anteriormente. Ao treinar um modelo preditivo, iremos verificar se essas features são relevantes para a modelagem como um todo.
#
# Em complemento, é possível analisar que, considerando um viés preditivo, nem todas as colunas da base serão utilizadas para a predição de sobrevivência dos passageiros do navio. Na prática, colunas como `Cabin`, `PassengerId`, `Ticket` e `Name`, por exemplo, não possuem significado prático para uma modelagem preditiva, sendo responsáveis apenas por informações chave de passageiros ou indicadores únicos de registros. Dessa forma, como próxima etapa, vamos aplicar um processo de seleção de features para eleger apenas as variáveis candidatas dentro de um contexto de modelagem.

# %% [markdown]
# ### Features Candidatas

# %%
# Definindo set inicial de features
TARGET = 'Survived'
TO_DROP = ['PassengerId', 'Name', 'Ticket', 'Cabin']
INITIAL_FEATURES = list(df.drop(TO_DROP, axis=1).columns)

# %% [markdown]
# Definidas as variáveis presentes no set inicial de features (variável `INITIAL_FEATURES`), é possível utilizar a classe `FiltraColunas()` do módulo `pycomp.ml.transformers` para aplicar o processo de _feature selection_ em atributos pré-selecionados.

# %%
# Importando classe
from pycomp.ml.transformers import FiltraColunas

# Aplicando transformador
selector = FiltraColunas(features=INITIAL_FEATURES)
df_slct = selector.fit_transform(df)

# Resultados
print(f'Dimensões do dataset original: {df.shape}')
print(f'Dimensões do dataset após seleção de features: {df_slct.shape}')
df_slct.head()
# Out:
# Dimensões do dataset original: (891, 19)
# Dimensões do dataset após seleção de features: (891, 15)
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked name_title  \
# 0         0       3    male  22.0      1      0   7.2500        S        Mr.
# 1         1       1  female  38.0      1      0  71.2833        C       Mrs.
# 2         1       3  female  26.0      0      0   7.9250        S      Miss.
# 3         1       1  female  35.0      1      0  53.1000        S       Mrs.
# 4         0       3    male  35.0      0      0   8.0500        S        Mr.
#
#   ticket_class cabin_class  name_length age_cat    fare_cat  family_size
# 0            A         NaN           23   20_40         0_8            2
# 1           PC           C           51   20_40  greater_50            2
# 2   STON_SOTON         NaN           22   20_40         0_8            1
# 3        OTHER           C           44   20_40  greater_50            2
# ...

# %% [markdown]
# Pelas dimensões resultantes, percebe-se que a aplicação da classe `FiltraColunas` resultou na redução de 4 colunas da base original.

# %% [markdown]
# ### Dados Duplicados

# %% [markdown]
# O tratamento de dados duplicados é um importante passo na preparação da base para o treinamento de modelos. Isso pois, eliminar duplicatas significa, também, eliminar redundância na base, permitindo aos modelos de machine learning uma convergência mais rápida aos mínimos locais/globais.
#
# Para realizar essa tarefa, será utilizada a classe `EliminaDuplicatas` do módulo `pycomp.ml.transformers` que, por sua vez, é responsável por simplesmente eliminar os registros duplicados de uma base de dados passada como input.

# %%
# Importing class
from pycomp.ml.transformers import EliminaDuplicatas

# Applying transformer
dup_dropper = EliminaDuplicatas()
df_nodup = dup_dropper.fit_transform(df_slct)

# Results
print(f'Total of duplicates before: {df_slct.duplicated().sum()}')
print(f'Total of duplicates after: {df_nodup.duplicated().sum()}')
# Out:
# Total of duplicates before: 17
# Total of duplicates after: 0

# %% [markdown]
# ### Alterando Tipos Primitivos

# %% [markdown]
# No decorrer das análises propostas na fase exploratória do projeto, foi possível perceber a presença de algumas colunas numéricas com significado categórico na base. Em outras palavras, tratam-se de colunas que, em sua origem, estão persistidas com tipos numéricos mas que, na prática, representam categorias relacionadas a alguma informação específica como podemos visualzar em, por exemplo, `Pclass`, `SibSp` e `Parch` (mais especificamente em `Pclass` do que nas demais e, a princípio, podemos considerar uma primeira versão trabalhando na transformação somente na coluna `Pclass`).
#
# Dessa forma, um passo importante para que os processos de preparação possam ser aplicados de forma correta, é a transformação dessas colunas numéricas em strings.

# %%
# Importando classe
from pycomp.ml.transformers import ModificaTipoPrimitivo

# Definições iniciais
cat_custom_features = ['Pclass']
mod_dict = {col: str for col in cat_custom_features}
print(f'Tipo primitivo das colunas alvo antes da transformação:\n')
print(df_nodup.dtypes[cat_custom_features])

# Criando objeto e aplicando transformação
dtype_mod = ModificaTipoPrimitivo(mod_dict=mod_dict)
df_mod = dtype_mod.fit_transform(df_nodup)
print(f'\n\nTipo primitivo das colunas alvo após a transformação:\n')
print(df_mod.dtypes[cat_custom_features])
# Out:
# Tipo primitivo das colunas alvo antes da transformação:
#
# Pclass    int64
# dtype: object
#
#
# Tipo primitivo das colunas alvo após a transformação:
#
# Pclass    object
# dtype: object

# %% [markdown]
# ### Dados de Treino e de Validação

# %% [markdown]
# Finalizando o que poderíamos chamar de _pipeline inicial_ do projeto, temos um passo importante responsável por separar a base de dados em treino e teste. Pensando em um futuro passo de modelagem, avaliar o resultado em diferentes bases é extremamente importante para tomar decisões a respeito da melhor solução prática a ser colocada em produção.
#
# Para isso, utilizaremos a classe `SplitDados` também do módulo `pycomp.ml.transformers` que, por sua vez, aplica essa separação na base e nos retorna dados de treino e validação devidamente separados.

# %%
# Importing class
from pycomp.ml.transformers import SplitDados

# Applying transformer
splitter = SplitDados(target='Survived')
X_train, X_val, y_train, y_val = splitter.fit_transform(df_nodup)

# Results
print(f'Shape of X_train: {X_train.shape}')
print(f'Shape of X_val: {X_val.shape}')
print(f'Shape of y_train: {y_train.shape}')
print(f'Shape of y_val: {y_val.shape}')
# Out:
# Shape of X_train: (699, 14)
# Shape of X_val: (175, 14)
# Shape of y_train: (699,)
# Shape of y_val: (175,)

# %% [markdown]
# Com isso, encerramos a primeira etapa referente a análise de transformadores a serem aplicados em um _pipeline inicial_ da base. A ideia é aplicar essas etapas comuns a base como um todo.
#
# A seguir, serão construídos pipelines específicos de acordo com o tipo primitivo de cada coluna. Dessa forma, teremos um _pipeline numérico_ e um _pipeline categórico_ que irão compor a segunda fase de transformação no processo de prep.

# %% [markdown]
# ## Pipeline Numérico

# %% [markdown]
# Antes de iniciar os passos referentes a construção de um pipeline numérico, é importante separar os atributos da nossa base de dados de acordo com seus respectivos tipos primitivos. Para isso, vamos criar duas listas diferentes contendo, em cada uma delas, as colunas categóricas e numéricas da base

# %%
# Separando features numéricas com significado categórico
cat_custom_features = ['Pclass']

# Separando dados por tipo primitivo
num_features = list(X_train.select_dtypes(exclude=['object', 'category']).columns)
cat_features = list(X_train.select_dtypes(include=['object', 'category']).columns)

# Filtrando DataFrames para testes
X_train_num = X_train[num_features]
X_train_cat = X_train[cat_features]

print(f'Atributos numéricos:\n{num_features}')
print(f'\nAtributos categóricos:\n{cat_features}')
# Out:
# Atributos numéricos:
# ['Age', 'SibSp', 'Parch', 'Fare', 'name_length', 'family_size']
#
# Atributos categóricos:
# ['Pclass', 'Sex', 'Embarked', 'name_title', 'ticket_class', 'cabin_class', 'age_cat', 'fare_cat']

# %% [markdown]
# Dessa forma, podemos então iniciar as etapas de construção de transformadores específicos para os tipos numéricos e categóricos da base.

# %% [markdown]
# ### Dados Nulos

# %% [markdown]
# Vimos, ao início da sessão 3. que algumas variáveis da base de dados possuem dados nulos. É preciso, de alguma forma, realizar o tratamento desses dados para uma futura inserção em modelos preditivos. Vamos resgatar essa análise de overview da base, utilizando agora apenas os dados de treino (atributos filtrados e tratados) no pipeline inicial.

# %%
# Novo overview
df_overview = data_overview(X_train)
data_overview(df=X_train).query('feature in @num_features')
# Out:
#         feature  qtd_null  pct_null    dtype  qtd_cat
# 1           Age       121  0.173104  float64        0
# 7         SibSp         0  0.000000    int64        0
# 8         Parch         0  0.000000    int64        0
# 9          Fare         0  0.000000  float64        0
# 12  name_length         0  0.000000    int64        0
# 13  family_size         0  0.000000    int64        0

# %% [markdown]
# A tabela acima nos mostra a necessidade de tratamento de dados nulos nas colunas `Age` e `Embarked`. Considerando a centralização de transformações em atributos numéricos nessa sessão, vamos considerar o preenchimento de dados nulos para a variável `Age` a partir da classe `SimpleImputer` do sklearn. Como estratégia estatística, podemos inserir a _mediana_ dessa variável para preenchimento.

# %%
# Importing library
from sklearn.impute import SimpleImputer

# Applying transformer
imputer = SimpleImputer(strategy='median')
X_train_num_imp = imputer.fit_transform(X_train_num)
X_train_num_imp = pd.DataFrame(X_train_num_imp, columns=num_features)

# Results
print(f'Null data before imputer: {X_train_num.isnull().sum().sum()}')
print(f'Null data after imputer: {X_train_num_imp.isnull().sum().sum()}')
# Out:
# Null data before imputer: 121
# Null data after imputer: 0

# %% [markdown]
# Excelente! A princípio, não iremos construir outros transformadores além do preenchimento dos dados nulos em atributos numéricos. Dessa forma, podemos partir para a preparação dos dados categóricos da base

# %% [markdown]
# ### Transformação Logaritma

# %% [markdown]
# Para validar o impacto da transformação logaritma nos modelos preditivos candidatos, opcionalmente vamos propor uma etapa no pipeline que aplique esse procedimento nas features numéricas presentes na base. Com isso, podemos validar se a performance final do modelo é sensível a esse tipo de transformação.

# %%
# Exemplo de distribuição
log_ex = 'Fare'
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(17, 7))
plot_distplot(df=X_train_num, col=log_ex, ax=axs[0], hist=True,
              title=f'Original {log_ex} Distribution')

tmp_data = X_train_num.copy()
tmp_data[log_ex] = tmp_data[log_ex].apply(lambda x: np.log1p(x))
plot_distplot(df=tmp_data, col=log_ex, ax=axs[1], color='mediumseagreen', hist=True, 
              title=f'{log_ex} After Log Transformation')

# %% [markdown]
# Duas medidas estatísticas altamente relevantes para análise de distribuição são `skew` e `kurtosis`. Através do [link](https://codeburst.io/2-important-statistics-terms-you-need-to-know-in-data-science-skewness-and-kurtosis-388fef94eeaa) é possível ter uma ideia clara sobre o que é cada uma dessas medidas e como interpretar distribuições contínuas através de seus valores.
#
# A transformação logaritma auxilia no aumento da performance para distribuições com `skewness` positiva (assimétricas à esquerda). Assim, vamos analisar novamente as features numéricas e rankear as principais features com oportunidade de melhoria através desse tipo de transformação.

# %%
from scipy.stats import skew, kurtosis

tmp_ov = data_overview(df=X_train_num_imp)
tmp_ov['skew'] = tmp_ov.query('feature in @num_features')['feature'].apply(lambda x: skew(X_train_num_imp[x]))
tmp_ov['kurtosis'] = tmp_ov.query('feature in @num_features')['feature'].apply(lambda x: kurtosis(X_train_num_imp[x]))
tmp_ov[~tmp_ov['skew'].isnull()].sort_values(by='skew', ascending=False).loc[:, ['feature', 'skew', 'kurtosis']]
# Out:
#        feature      skew   kurtosis
# 3         Fare  4.624525  31.456252
# 1        SibSp  3.609052  17.045041
# 5  family_size  2.686255   8.970667
# 2        Parch  2.635933   9.152340
# 4  name_length  1.400023   2.539764
# 0          Age  0.492413   0.737518

# %% [markdown]
# A tabela acima mostra uma relação das features através de suas medidas de simetria `skewness` e `kurtosis`. No bloco de código abaixo, iremos executar a classe `DynamicLogTransformation` que, por sua vez, tem o papel de aplicar a transformação logaritma em uma base de dados em um pipeline de preparação. A vantagem dessa classe é a definição prévia de uma lista de features as quais a transformação será aplicada, sendo esta definida pelo usuário.

# %%
# Importando classe
from pycomp.ml.transformers import DynamicLogTransformation

# Definindo parâmetros
COLS_TO_LOG = ['Fare']
log_tr = DynamicLogTransformation(num_features=num_features, cols_to_log=COLS_TO_LOG)
X_train_num_ori = X_train_num_imp.copy()
X_train_num_log = log_tr.fit_transform(X_train_num_imp)

# Verificando alguns resultados
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(17, 7))

plot_distplot(df=df, col=COLS_TO_LOG[0], ax=axs[0], hist=True,
              title=f'{COLS_TO_LOG[0]} Distribution $Before$ \nLog Transformation')
plot_distplot(df=X_train_num_log, col=COLS_TO_LOG[0], ax=axs[1], hist=True, color='mediumseagreen',
              title=f'{COLS_TO_LOG[0]} Distribution $After$ \nLog Transformation')    

plt.tight_layout()

# %% [markdown]
# Adicionalmente, é válido citar que a class e `DynamicLogTransformation` possui um atributo booleano chamado `application` que pode ser utilizado futuramente para interações em `GridSearch` ou `RandomizedSearch`. Seu objetivo é possibilitar análises em performance de modelos **com** ou **sem** a transformação logaritma.

# %% [markdown]
# ### Normalização

# %% [markdown]
# Uma outra forma interessante em aplicar um procedimento que auxilie um dado modelo preditivo a converger para o valor ótimo de forma mais rápida é dado pela `normalização` dos dados. Para o contexto de machine learning, é possível utilizar classes prontas do `sklearn` como, por exemplo, `MinMaxScaler` ou `StandardScaler`.
#
# Este tipo de padronização/normalização poderá ser opcionalmente aplicada diretamente no pipeline numérico. Abaixo, será demonstrado um exemplo de como essa transformação pode ser aplicada na nossa base de dados numérica.

# %%
# Importando classe
from pycomp.ml.transformers import DynamicScaler

scaler = DynamicScaler(scaler_type='Standard')
X_train_num_scaled = scaler.fit_transform(X_train_num_log)
X_train_num_scaled = pd.DataFrame(X_train_num_scaled, columns=num_features)
X_train_num_scaled.head()
# Out:
#         Age     SibSp     Parch      Fare  name_length  family_size
# 0  0.261284  0.426740  0.787046  0.096715    -0.220103     0.681048
# 1  0.714917 -0.485465 -0.486438 -0.812539    -0.953729    -0.573373
# 2 -0.116744 -0.485465 -0.486438 -0.834469    -0.429710    -0.573373
# 3  1.017339  0.426740  0.787046  0.340295    -0.953729     0.681048
# 4  0.110073  0.426740  0.787046  0.096715     1.980776     0.681048

# %% [markdown]
# Com isso, encerramos as etapas de preparação no pipeline numérico do projeto. Futuramente, vamos consolidar cada um destes _steps_ em um bloco único de preparação utilizando a classe `Pipeline` do `sklearn`. Como próximas etapas, vamos analisar a parte categórica do conjunto.

# %% [markdown]
# ## Pipeline Categórico

# %% [markdown]
# Para esta sessão, sabemos que já existe a necessidade de preenchimento de dados nulos provenientes da coluna `Embarked`. Na análise realizada na sessão 3.2.1 anterior, vimos que tratam-se de apenas 2 registros nulos para a coluna que informa o porto de embarque de cada passageiro.
#
# Para tratar esse caso, podemos configurar o nosso método de encoding para considerar uma coluna adicional para os dados missing em determinadas colunas, como no caso da feature `Embarked`.

# %% [markdown]
# ### Encoding

# %% [markdown]
# Um passo extremamente importante envolvendo atributos categóricos da base é a aplicação de um processo conhecido como `encoding` dos dados. A importância desse _step_ se dá pela incapacidade da maioria de modelos de machine learning em ler entradas categóricas de uma base de dados fornecida como input. Isto pois, no backgorund dos modelos mais comuns, são realizados diversos cálculos numéricos em prol da minimização de uma função custo e alcance de um erro mínimo, o que de fato fica impossibilitado na presença de variávels categóricas.
#
# Para isso, o processo de `encoding` existe para aplicar uma espécie de "codificação" nos dados categóricos, muitas vezes os separando em diferentes colunas, uma para cada entrada diferente. Neste contexto, podemos utilizar a classe `DummiesEncoding()` do módulo `pycomp.ml.transformers` que, por sua vez, é responsável por aplicar esse processo de forma automática.

# %%
# Importando classe
from pycomp.ml.transformers import DummiesEncoding

# Criando objeto e aplicando transformador
encoder = DummiesEncoding(cat_features_ori=cat_features, dummy_na=True)
X_train_cat_enc = encoder.fit_transform(X_train_cat)

# Resultados
print(f'Shape before encoding: {X_train_cat.shape}')
print(f'Shape after encoding: {X_train_cat_enc.shape}')
X_train_cat_enc.head()
# Out:
# Shape before encoding: (699, 8)
# Shape after encoding: (699, 42)
#      Pclass_1  Pclass_2  Pclass_3  Pclass_nan  Sex_female  Sex_male  Sex_nan  \
# 548         0         0         1           0           0         1        0
# 400         0         0         1           0           0         1        0
# 778         0         0         1           0           0         1        0
# 314         0         1         0           0           0         1        0
# 328         0         0         1           0           1         0        0
#
#      Embarked_C  Embarked_Q  Embarked_S  Embarked_nan  name_title_Master.  \
# 548           0           0           1             0                   0
# 400           0           0           1             0                   0
# 778           0           1           0             0                   0
# 314           0           0           1             0                   0
# ...

# %% [markdown]
# ## Pipelines Completos

# %% [markdown]
# Após passarmos por 3 grandes blocos envolvendo a configuração e aplicação de classes específicas para a preparação da nossa base de dados, é possível consolidar esses passos em objetos nativos a partir da classe `Pipeline` do `sklearn`.
#
# Nessa sessão, iremos construir pipelines capazes de consolidar todas as etapas detalhadas até aqui em objetos únicos de preparação. Tais objetos serão extremamente importante na reprodução desse fluxo e também na aplicação padronizada das etapas em novos dados a serem recebidos (dados de teste, por exemplo). Assim, considerando os tópicos anteriores, iremos construir:
#
# 1. **_initial_pipeline:_** pipeline responsável por receber uma base bruta de dados e aplicar transformações comuns a todos os atributos;
# 2. **_prep_pipeline:_** pipeline responsável por consolidar as transformações aplicadas em dados numéricos e categóricos em um único objeto.

# %%
# Importando bibliotecas
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# Definindo variáveis globais
TARGET = 'Survived'

INITIAL_FEATURES = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'name_title', 
                    'ticket_class', 'cabin_class', 'name_length', 'age_cat', 'fare_cat', 'family_size']
INITIAL_PRED_FEATURES = [col for col in INITIAL_FEATURES if col not in TARGET]

DTYPE_MODIFICATION_DICT = {'Pclass': str}

NUM_FEATURES = ['Age', 'SibSp', 'Parch', 'Fare', 'name_length', 'family_size']
CAT_FEATURES = ['Pclass', 'Sex', 'Embarked', 'name_title', 'ticket_class', 'cabin_class', 'age_cat', 'fare_cat']

CAT_FEATURES_FINAL = ['Pclass_1', 'Pclass_2', 'Pclass_3', 'Pclass_nan', 'Sex_female', 'Sex_male', 'Sex_nan',
                      'Embarked_C', 'Embarked_Q', 'Embarked_S', 'Embarked_nan', 'name_title_Master.', 
                      'name_title_Miss.', 'name_title_Mr.', 'name_title_Mrs.', 'name_title_OTHER',
                      'name_title_nan', 'ticket_class_A', 'ticket_class_OTHER', 'ticket_class_PC', 
                      'ticket_class_SC', 'ticket_class_STON_SOTON', 'ticket_class_nan', 'cabin_class_A', 
                      'cabin_class_B', 'cabin_class_C', 'cabin_class_D', 'cabin_class_E', 'cabin_class_FGT', 
                      'cabin_class_nan', 'age_cat_0_10', 'age_cat_10_20', 'age_cat_20_40', 'age_cat_40_60',
                      'age_cat_greater_60', 'age_cat_nan', 'fare_cat_0_8', 'fare_cat_15_25', 
                      'fare_cat_25_50', 'fare_cat_8_15', 'fare_cat_greater_50', 'fare_cat_nan']

MODEL_FEATURES = NUM_FEATURES + CAT_FEATURES_FINAL

# Variáveis de pipeline numérico
NUM_STRATEGY_IMPUTER = 'median'
SCALER_TYPE = None
LOG_APPLICATION = False
COLS_TO_LOG = ['Fare', 'Age']

# Variáveis de pipeline categórico
ENCODER_DUMMY_NA = True
NAME_TITLE = True
CABIN_CLASS = True
TICKET_CLASS = True
NAME_LENGTH = True
AGE_CAT = True
FARE_CAT = True
FAMILY_SIZE = True

# Construindo pipeline inicial (treino e predição)
initial_train_pipeline = Pipeline([
    ('feature_adder', CustomFeaturesTitanic(name_title=NAME_TITLE, cabin_class=CABIN_CLASS, 
                                            ticket_class=TICKET_CLASS, name_length=NAME_LENGTH,
                                            age_cat=AGE_CAT, fare_cat=FARE_CAT, family_size=FAMILY_SIZE)),
    ('col_filter', FiltraColunas(features=INITIAL_FEATURES)),
    ('dtype_modifier', ModificaTipoPrimitivo(mod_dict=DTYPE_MODIFICATION_DICT)),
    ('dup_dropper', EliminaDuplicatas())
])

initial_pred_pipeline = Pipeline([
    ('feature_adder', CustomFeaturesTitanic(name_title=NAME_TITLE, cabin_class=CABIN_CLASS, 
                                            ticket_class=TICKET_CLASS, name_length=NAME_LENGTH,
                                            age_cat=AGE_CAT, fare_cat=FARE_CAT, family_size=FAMILY_SIZE)),
    ('col_filter', FiltraColunas(features=INITIAL_PRED_FEATURES)),
    ('dtype_modifier', ModificaTipoPrimitivo(mod_dict=DTYPE_MODIFICATION_DICT))
])

# Construindo pipeline numérico
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy=NUM_STRATEGY_IMPUTER)),
    ('log_transformer', DynamicLogTransformation(application=LOG_APPLICATION, num_features=NUM_FEATURES, 
                                                 cols_to_log=COLS_TO_LOG)),
    ('scaler', DynamicScaler(scaler_type=SCALER_TYPE))
])

# Construindo pipeline categórico
cat_pipeline = Pipeline([
    ('encoder', DummiesEncoding(dummy_na=ENCODER_DUMMY_NA, cat_features_final=CAT_FEATURES_FINAL))
])

# Criando pipeline completo
prep_pipeline = ColumnTransformer([
    ('num', num_pipeline, NUM_FEATURES),
    ('cat', cat_pipeline, CAT_FEATURES)
])

# %%
# Lendo base bruta de dados
df = pd.read_csv(os.path.join(DATA_PATH, TRAIN_FILENAME))

# Executando pipeline inicial de treino
df_prep = initial_train_pipeline.fit_transform(df)

# Separando dados de treino e de teste
X_train, X_val, y_train, y_val = train_test_split(df_prep.drop(TARGET, axis=1), df_prep[TARGET].values,
                                                  test_size=.20, random_state=42)

# Executando pipelines de preparação
X_train_prep = prep_pipeline.fit_transform(X_train)

X_val_prep = prep_pipeline.fit_transform(X_val)

# Validando dimensões
print(f'Dimensões de X_train_prep: {X_train_prep.shape}')
print(f'Dimensões de X_val_prep: {X_val_prep.shape}')
print(f'\nQuantidade de features consideradas: {len(MODEL_FEATURES)}')
# Out:
# Dimensões de X_train_prep: (699, 48)
# Dimensões de X_val_prep: (175, 48)
#
# Quantidade de features consideradas: 48

# %% [markdown]
# Perfeito! Neste ponto do projeto, estamos prontos para iniciar a etapa de modelagem preditiva em busca de construir um modelo capaz de retornar a probabilidade de sobrevivência dos passageiros do Titanic frente as variáveis consideradas para análise. Antes de mergulhar nos tópicos relacionados a predição de sobrevivência, vamos utilizar a base final preparada para plotar uma matriz de correlação em relação a variável target do modelo (`Survived`). O objetivo desse estudo é ter uma noção prévia sobre as variáveis mais importantes presentes na base.

# %%
# Preparando um dataset final
df_prep = pd.DataFrame(X_train_prep, columns=MODEL_FEATURES)
df_prep['Survived'] = y_train

# Plotando matriz de correlação
plot_corr_matrix(df=df_prep, corr_col='Survived', figsize=(12, 12), cbar=False, n_vars=15)

# %%
plot_corr_matrix(df=df_prep, corr='negative', corr_col='Survived', figsize=(12, 12), cbar=False, n_vars=15)

# %% [markdown]
# # Modelagem: Prevendo Sobrevivência

# %% [markdown]
# Por fim, a tão esperada sessão onde finalmente realizamos o treinamento de modelos de machine learning em busca do melhor algoritmo capaz de retornar a probabilidade de sobrevivência dos passageiros e tripulantes do navio frente ao naufrágio.
#
# Para chegar nesta etapa, passamos por uma densa sessão de análise exploratória que nos auxiliou grandemente no levantamento de insights e em um entendimento completo da base de dados disponível, além de uma rica sessão onde foi possível construir pipelines definitivos para preparação do dataset.
#
# Dessa forma, podemos separar a etapa de modelagem em:
#
# 1. **_Definições iniciais_**, onde iremos definir os blocos fundamentais para o início do treinamento, como por exemplo, os modelos utilizados e seus respectivos hiperparâmetros de busca;
# 2. **_Treinamento_**, onde iremos aplicar, de fato, o trainamento dos modelos selecionados na etapa anterior. Para isso, utilizaremos, mais uma vez, poderosas funcionalidades do pacote `pycomp` a partir de seu módulo `pycomp.ml.trainer`;
# 3. **_Avaliação_**, onde, após o devido treinamento dos modelos candidatos, iremos analisar as performances individuais de cada um frente a tarefa de predição proposta.

# %% [markdown]
# ## Definições Iniciais

# %% [markdown]
# Como mencionado anteriormente, esta é a etapa onde preparamos as estruturas para o início do treinamento. Aqui, o objetivo é importar e preparar os modelos de classificação a serem utilizados para a predição de sobrevivência dos passageiros.

# %%
# Importando modelos
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# Instanciando objetos
dtree = DecisionTreeClassifier()
forest = RandomForestClassifier()
lgbm = LGBMClassifier()
xgb = XGBClassifier()
adaboost = AdaBoostClassifier()
gradboost = GradientBoostingClassifier()

# Criando dicionário set_classifiers
model_obj = [dtree, forest, lgbm, xgb, adaboost, gradboost]
model_names = [type(model).__name__ for model in model_obj]
set_classifiers = {name: {'model': obj, 'params': {}} for (name, obj) in zip(model_names, model_obj)}

print(f'Classifiers that will be trained on next steps: \n\n{model_names}')
# Out:
# Classifiers that will be trained on next steps:
#
# ['DecisionTreeClassifier', 'RandomForestClassifier', 'LGBMClassifier', 'XGBClassifier', 'AdaBoostClassifier', 'GradientBoostingClassifier']

# %% [markdown]
# ## Treinamento de Modelos

# %% [markdown]
# Uma vez preparada a estrutura de modelagem a partir de objetos específicos, como por exemplo, o dicionário `set_classifiers`, é possível agora importar a classe `ClassificadorBinario` presente no módulo `pycomp.ml.trainer` para realizar todo o treinamento e avaliação dos modelos candidatos.
#
# Essa classe foi desenvolvida com o intuito de facilitar grandemente o trabalho do analista/cientista em termos de implementação de códigos para treinar, avaliar e otimizar modelos preditivos de classificação binária. Seus métodos comportam poderosas funcionalidades que realizam diversas ações com apenas uma chamada.

# %%
# Importando classe
from pycomp.ml.trainer import ClassificadorBinario

# Criando objeto e realizando treinamento
trainer = ClassificadorBinario()
trainer.fit(set_classifiers, X_train_prep, y_train, random_search=False)
# Out:
# DEBUG;2021-02-03 20:34:29;trainer.py;trainer;229;Treinando modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:34:29;trainer.py;trainer;229;Treinando modelo RandomForestClassifier
# DEBUG;2021-02-03 20:34:29;trainer.py;trainer;229;Treinando modelo LGBMClassifier
# DEBUG;2021-02-03 20:34:30;trainer.py;trainer;229;Treinando modelo XGBClassifier
# DEBUG;2021-02-03 20:34:30;trainer.py;trainer;229;Treinando modelo AdaBoostClassifier
# DEBUG;2021-02-03 20:34:30;trainer.py;trainer;229;Treinando modelo GradientBoostingClassifier

# %% [markdown]
# O método `fit()` do objeto `trainer` criado tem a responsabilidade de realizar o treinamento dos modelos encapsulados no dicionário `set_classifiers` criado na etapa de definições iniciais.
#
# Configurando o método para aplicar também o processo de `RandomizedSearchCV` (busca aleatória dos melhores hiperparâmetros de cada algoritmo), é possível construir modelos otimizados de acordo com o espaço de busca passado no dicionário `set_classifiers`.

# %% [markdown]
# ## Avaliando Performance

# %% [markdown]
# Uma vez treinados os modelos candidatos através do método `fit()`, é possível então avaliar a performance obtida em cada um dos casos, retornando assim as principais métricas de classificação capazes de nos indicar o melhor direcionamento para a dada tarefa.
#
# Para realizar esse processo, podemos utilizar os métodos `evaluate_performance()` ou `plot_metrics()` do objeto `trainer`. No primeiro caso, o retorno é um DataFrame analítico contendo o resultado da avaliação de cada modelo frente as principais métricas. Já no segundo caso, o retorno é uma análise visual das métricas para cada um dos modelos.

# %%
# Resultados do treinamento (analítico)
metrics = trainer.evaluate_performance(X_train_prep, y_train, X_val_prep, y_val)
metrics
# Out:
# DEBUG;2021-02-03 20:34:30;trainer.py;trainer;301;Computando métricas do modelo DecisionTreeClassifier utilizando validação cruzada com 5 K-folds
# INFO;2021-02-03 20:34:30;trainer.py;trainer;333;Métricas computadas com sucesso nos dados de treino em 0.168 segundos
# DEBUG;2021-02-03 20:34:30;trainer.py;trainer;366;Computando métricas do modelo DecisionTreeClassifier utilizando dados de teste
# INFO;2021-02-03 20:34:30;trainer.py;trainer;395;Métricas computadas com sucesso nos dados de teste em 0.008 segundos
# DEBUG;2021-02-03 20:34:30;trainer.py;trainer;301;Computando métricas do modelo RandomForestClassifier utilizando validação cruzada com 5 K-folds
# INFO;2021-02-03 20:34:34;trainer.py;trainer;333;Métricas computadas com sucesso nos dados de treino em 4.357 segundos
# DEBUG;2021-02-03 20:34:34;trainer.py;trainer;366;Computando métricas do modelo RandomForestClassifier utilizando dados de teste
# ...

# %% [markdown]
# Como mencionado anteriormente, o método `evaluate_performance()` retorna uma tabela analítica contendo a performance de cada modelo (em treino e teste) para as principais métricas de avaliação de modelos de classificação. A partir dessa tabela, é possível pontuar que, em termos de acurácia, o modelo `RandomForest` apresentou uma performance ligeiramente superior aos demais, apesar do alto tempo necessário para realização dos cálculos.
#
# Pensando em fixar, de fato, um objetivo de otimização para eleger o melhor modelo preditivo, vamos considerar a `acurária` como a métrica a ser utilizada para essa decisão. Uma outra forma de analisar a performance dos modelos candidatos é a partir do método `plot_metrics()`. Seu resultado pode ser visto logo abaixo:

# %%
# Analisando graficamente os resultados
trainer.plot_metrics()
# Out:
# DEBUG;2021-02-03 20:34:42;trainer.py;trainer;633;Iniciando plotagem gráfica das métricas dos classificadores
# DEBUG;2021-02-03 20:34:42;trainer.py;trainer;637;Retornando métricas via validação cruzada para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:34:42;trainer.py;trainer;637;Retornando métricas via validação cruzada para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:34:45;trainer.py;trainer;637;Retornando métricas via validação cruzada para o modelo LGBMClassifier
# DEBUG;2021-02-03 20:34:46;trainer.py;trainer;637;Retornando métricas via validação cruzada para o modelo XGBClassifier
# DEBUG;2021-02-03 20:34:47;trainer.py;trainer;637;Retornando métricas via validação cruzada para o modelo AdaBoostClassifier
# DEBUG;2021-02-03 20:34:49;trainer.py;trainer;637;Retornando métricas via validação cruzada para o modelo GradientBoostingClassifier
# DEBUG;2021-02-03 20:34:51;trainer.py;trainer;664;Modificando DataFrame de métricas para plotagem gráfica
# ...

# %% [markdown]
# Graficamente, é possível visualizar a superioridade do modelo `RandomForest` em termos de acurácia. Na primeira linha, tem-se uma análise de boxplot considerando os `k` folds utilizados na validação cruzada e, a partir dela, é possível visualizar a dispersão de cada rodada de avaliação para cada modelo candidato. Na segunda linha da plotagem, tem-se uma análise de média por métrica e por modelo candidato.

# %% [markdown]
# ___
# * **_Features mais relevantes_**
# ___

# %% [markdown]
# Aprimorando ainda mais a análise dos resultados, é possível retornar a importância que cada feature da base teve no resultado final da predição. Vejamos as features mais importantes consideradas por cada modelo a partir do método `plot_feature_importance()`

# %%
# Análise das features mais importantes pra cada modelo
trainer.plot_feature_importance(features=MODEL_FEATURES)
# Out:
# DEBUG;2021-02-03 20:34:52;trainer.py;trainer;724;Inicializando plotagem das features mais importantes para os modelos
# DEBUG;2021-02-03 20:34:52;trainer.py;trainer;735;Extraindo importância das features para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:34:52;trainer.py;trainer;748;Plotando gráfico de importância das features para o modelo DecisionTreeClassifier
# INFO;2021-02-03 20:34:52;trainer.py;trainer;758;Gráfico de importância das features plotado com sucesso para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:34:52;trainer.py;trainer;735;Extraindo importância das features para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:34:52;trainer.py;trainer;748;Plotando gráfico de importância das features para o modelo RandomForestClassifier
# INFO;2021-02-03 20:34:52;trainer.py;trainer;758;Gráfico de importância das features plotado com sucesso para o modelo RandomForestClassifier
# ...

# %% [markdown]
# Analisando o log do método, percebe-se que o modelo `LogisticRegression` não possui o método `feature_importances_()` e, dessa forma, fica impossibilitado o cálculo e retorno dessa frente para este modelo. Considerando então os modelos `DecisionTrees` e `RandomForest`, os gráficos de barra acima indicam as principais features com maior relevância para a predição de sobrevivência dos passageiros ao naufrágio do Titanic.
#
# Em geral, pode-se afirmar que as variáveis de gênero (`Sex_male` e `Sex_female`), `Fare` e `PClass` tiveram um alto impacto na análise e predição de sobrevivência dos passageiros (algo realmente levantado na fase de exploração dos dados).

# %% [markdown]
# ___
# * **_Matriz de Confusão_**
# ___

# %% [markdown]
# Em modelos de classificação binária, é comum realizar análises individuais nos Verdadeiros Positivos, Verdadeiros Negativos, Falsos Positivos e Falsos Negativos, ou seja, em basicamente todos os indicadores que compõe as principais métricas de classificação visualizadas anteriormente. Para isso, a ferramenta utilizada é a _matriz de confusão_ que, por sua vez, tem o objetivo de consolidar todos esses indicadores em um formato visual de matriz.
#
# Para realizar essa análise, é possível executar o método `plot_confusion_matrix()` do objeto `trainer`. O resultado será dado por duas matrizes de confusão para cada modelo utilizado (uma para os dados de treino e outra utilizando os dados de teste). Vejamos:

# %%
# Plotando matriz de confusão
trainer.plot_confusion_matrix()
# Out:
# DEBUG;2021-02-03 20:34:56;trainer.py;trainer;854;Inicializando plotagem da matriz de confusão para os modelos
# DEBUG;2021-02-03 20:34:56;trainer.py;trainer;862;Retornando dados de treino e teste para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:34:56;trainer.py;trainer;875;Realizando predições para os dados de treino e teste (DecisionTreeClassifier)
# DEBUG;2021-02-03 20:34:56;trainer.py;trainer;883;Gerando matriz de confusão para o modelo DecisionTreeClassifier
# INFO;2021-02-03 20:34:56;trainer.py;trainer;896;Matriz de confusão gerada para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:34:56;trainer.py;trainer;862;Retornando dados de treino e teste para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:34:56;trainer.py;trainer;875;Realizando predições para os dados de treino e teste (RandomForestClassifier)
# DEBUG;2021-02-03 20:34:58;trainer.py;trainer;883;Gerando matriz de confusão para o modelo RandomForestClassifier
# ...

# %% [markdown]
# ___
# * **_Curva ROC_**
# ___

# %% [markdown]
# Em alguns casos, datasets com variável target desbalanceada, ou seja, uma quantidade extremamente pequena de registros para uma determinada classe, pode apresentar altos viéses para as métricas clássicas de avaliação de modelos de classificação. Dessa forma, uma solução possível seja analisar os resultados em termos de `score` ou `probabilidade` ao invés de métricas fixas.
#
# Nesses casos, é possível analisar a curva ROC dos modelos para verificar se estes estão performando bem frente ao objetivo de negócio a ser atingido. Para isso, podemos executar o método `plot_roc_curve()` do objeto `trainer`.

# %%
# Visualizando curva ROC
trainer.plot_roc_curve()
# Out:
# DEBUG;2021-02-03 20:35:02;trainer.py;trainer;935;Inicializando plotagem da curva ROC para os modelos
# DEBUG;2021-02-03 20:35:02;trainer.py;trainer;941;Retornando labels e scores de treino e de teste para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:02;trainer.py;trainer;954;Calculando FPR, TPR e AUC de treino e teste para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:02;trainer.py;trainer;967;Plotando curva ROC de treino e teste para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:02;trainer.py;trainer;941;Retornando labels e scores de treino e de teste para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:35:02;trainer.py;trainer;954;Calculando FPR, TPR e AUC de treino e teste para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:35:02;trainer.py;trainer;967;Plotando curva ROC de treino e teste para o modelo RandomForestClassifier
# ...

# %% [markdown]
# Analisando as curvas acima de treino e de teste, bem como a métrica `roc_auc` (Area Under the Curve) na legenda de cada série, percebe-se que os modelos `RandomForest` e `LogisticRegression` apresentam uma melhor performance em relação ao modelo `DecisionTrees`. Futuramente, caso a métrica `roc_auc` se torne o objetivo de otimização dessa tarefa, podemos levar a análise acima em consideração para decidir o melhor algoritmo.

# %% [markdown]
# ___
# * **_Distribuição de probabilidades_**
# ___

# %% [markdown]
# Complementando a análise e os comentários acima, em alguns casos é extremamente relavante observar como os scores (ou probabilidades) dos modelos estão distribuídos em relação ao todo. Tal análise é importante para verificar se os classificadores estão, de fato, separando bem as classes positiva e negativa, proporcionando assim uma visão clara sobre os possíveis erros em cada faixa de score retornada.
#
# Esta visão pode ser retornada através do método `plot_score_distribution()` do objeto `trainer`.

# %%
# Visualizando distribuição de scores
trainer.plot_score_distribution()
# Out:
# DEBUG;2021-02-03 20:35:03;trainer.py;trainer;1026;Inicializando plotagem da distribuição de score para os modelos
# DEBUG;2021-02-03 20:35:03;trainer.py;trainer;1035;Retornando labels e scores de treino e de teste para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:03;trainer.py;trainer;1048;Plotando distribuição de score de treino e teste para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:03;trainer.py;trainer;1035;Retornando labels e scores de treino e de teste para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:35:03;trainer.py;trainer;1048;Plotando distribuição de score de treino e teste para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:35:03;trainer.py;trainer;1035;Retornando labels e scores de treino e de teste para o modelo LGBMClassifier
# DEBUG;2021-02-03 20:35:03;trainer.py;trainer;1048;Plotando distribuição de score de treino e teste para o modelo LGBMClassifier
# ...

# %% [markdown]
# As curvas acima representam a distribuição dos scores de cada um dos modelos treinados, considerando os dados de treino e de teste. A quebra pelas classes positiva e negativa presentes na base (`y=1` e `y=0`) indicam como cada algoritmo realizou a separação dos scores e o quão bom cada um pode ser nessa diferenciação considerando a probabilidade de cada classe entre 0 e 1.
#
# Na prática, a leitura das curvas se dá pela densidade de elementos de cada uma das classes quando o score de probabilidade se encontra nas faixas determinadas pelo eixo x. Exemplificando a partir das curvas pro modelo `RandomForest` (última linha da figura), é possível notar que, quando a probabilidade retornada pelo modelo se encontra entre 0 e 0.4, existe uma alta densidade de elementos da classe negativa (curva azul), o que é um bom sinal. Por outro lado, quando o modelo retorna altas probabilidades, a densidade de elementos da classe positiva é extremamente maior (curva vermelha).

# %% [markdown]
# ___
# * **_Distribuição do score em faixas_**
# ___

# %% [markdown]
# Uma outra forma de analisar a distribuição do score de probabilidade dos modelos é através de sua separação em faixas específicas de análise. Assim, é possível analisar a volumetria de cada faixa de score considerando as diferentes classes presentes na base, abrindo a possibilidade de verificar, de fato, se os modelos estão separando as classes em uma abordagem discreta.
#
# Para isso, podemos utilizar o método `plot_score_bins()` do objeto `trainer` tal qual demonstrado abaixo:

# %%
# Analisando score em faixas
trainer.plot_score_bins()
# Out:
# DEBUG;2021-02-03 20:35:07;trainer.py;trainer;1102;Inicializando plotagem de distribuição de score em faixas para os modelos
# DEBUG;2021-02-03 20:35:08;trainer.py;trainer;1115;Calculando parâmetros de plotagem para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:08;trainer.py;trainer;1144;Plotando distribuição do score em faixas para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:08;trainer.py;trainer;1163;Plotando percentual de volumetria da faixa para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:08;trainer.py;trainer;1115;Calculando parâmetros de plotagem para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:35:08;trainer.py;trainer;1144;Plotando distribuição do score em faixas para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:35:08;trainer.py;trainer;1163;Plotando percentual de volumetria da faixa para o modelo RandomForestClassifier
# ...

# %% [markdown]
# Assim como visto na distribuição contínua anteriormente, o objetivo dessa análise em faixas também é verificar se os modelos estão separando adequadamente as classes a partir das faixas. Realizando a leiutra do resultado para o modelo `RandomForest` (última linha da figura), percebe-se um crescimento do volume de registros pertencentes a classe positiva (`y=1`) conforme o crescimento das faixas do eixo x, indicando assim que altos scores estão, em geral, relacionados a classe positiva (cenário esperado).

# %% [markdown]
# ___
# * **_Curva de aprendizado dos modelos_**
# ___

# %% [markdown]
# Uma ferramenta extremamente poderosa para verificar se os modelos utilizados sofrem de algum tipo de problema relacionado a bias ou variância (underfitting ou overfitting) são as _curvas de aprendizado_. Com elas, é possível verificar a evolução dos erros obtidos pelos modelos, em treino e em validação, a partir de números específicos de amostras utilizadas para tais cálculos.
#
# Na prática, é definido um "passo" de evolução de amostras e, sequencialmente, o modelo é treinado utilizando uma quantidade N + "passo" de amostras e seus respectivos erros são computados em treino e validação. O resultado são curvas de evolução mostrando o comportamento do erro relacionado ao aumento do número de amostras utilizadas no cálculo. Para realizar essa análise, temos o método `plot_learning_curve()` do objeto `trainer`.

# %%
# Analisando curva de aprendizado
trainer.plot_learning_curve()
# Out:
# DEBUG;2021-02-03 20:35:14;trainer.py;trainer;1227;Inicializando plotagem da curvas de aprendizado dos modelos
# DEBUG;2021-02-03 20:35:14;trainer.py;trainer;1235;Retornando parâmetros pro modelo DecisionTreeClassifier e aplicando método learning_curve
# DEBUG;2021-02-03 20:35:14;trainer.py;trainer;1253;Plotando curvas de aprendizado de treino e validação para o modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:14;trainer.py;trainer;1235;Retornando parâmetros pro modelo RandomForestClassifier e aplicando método learning_curve
# DEBUG;2021-02-03 20:35:22;trainer.py;trainer;1253;Plotando curvas de aprendizado de treino e validação para o modelo RandomForestClassifier
# DEBUG;2021-02-03 20:35:22;trainer.py;trainer;1235;Retornando parâmetros pro modelo LGBMClassifier e aplicando método learning_curve
# DEBUG;2021-02-03 20:35:23;trainer.py;trainer;1253;Plotando curvas de aprendizado de treino e validação para o modelo LGBMClassifier
# ...

# %% [markdown]
# Analisando as curvas, é possível concluir que os modelos não sofrem problemas graves de overfitting, dado que o erro nos dados de treino e de validação são bem semelhantes no final das 500 amostras. Para analisar outros cenários possíveis, o link de referência poderá ser de grande utilidade: https://www.dataquest.io/blog/learning-curves-machine-learning/

# %% [markdown]
# ___
# * **_Análise shap das variáveis_**
# ___

# %% [markdown]
# Por fim, finalizando o bloco de análise de performance dos modelos treinados, tem-se a análise `shap` como uma poderosa forma de analisar o impacto de cada uma das features da base em um determinado modelo preditivo. Diferente da análise de `feature importances` realizada anteriormente, a análise shap permite visualizar o impacto das features de acordo com seu valor absoluto. Em outras palavras, pode-se verificar se um valor elevado (ou extremamente baixo) de uma determinada feature pode impactar significante no output do modelo.
#
# Para essa rica análise, podemos utilizar o método `plot_shap_analysis()` do objeto `trainer`, passando, como principal argumento, o nome de um modelo já treinado pela classe e presente no atributo `classifiers_info`.

# %%
# Realizando análise shap
trainer.plot_shap_analysis(model_name='XGBClassifier', features=MODEL_FEATURES)
# Out:
# DEBUG;2021-02-03 20:35:37;trainer.py;trainer;1304;Explicando o modelo XGBClassifier através da análise shap
# DEBUG;2021-02-03 20:35:37;trainer.py;trainer;1312;Retornando parâmetros da classe para o modelo XGBClassifier
# DEBUG;2021-02-03 20:35:37;trainer.py;trainer;1322;Criando explainer e gerando valores shap para o modelo XGBClassifier
# DEBUG;2021-02-03 20:35:38;trainer.py;trainer;1335;Plotando análise shap para o modelo XGBClassifier

# %% [markdown]
# Como mencionado anteriormente, a análise shap permite cruzar o valor de cada feature e seu respectivo na resposta final do modelo. Como exemplo de leitura, o resultado obtido para a variável `Sex_male` indica que, quanto maior seu valor (mancha vermelha), menor seu impacto para o resultado do modelo (lado esquerdo do eixo x). Em uma análise mais técnica e resumida, é possível dizer que, quanto maior o valor de `Sex_male` (ou seja, quanto mais próximo do gênero masculino), menos o valor da probabilidade (baixa chance de sobrevivência).
#
# Analogamente, a leitura para a variável `Sex_female` indica o contrário: passageiros do gênero feminino tiveram maior chance de sobrevivência o que, de fato, foi investigado e levantado na fase exploratória do projeto.

# %% [markdown]
# ## Fluxo de Treino e Avaliação

# %% [markdown]
# Ao longo de todo o projeto e, principalmente nessa sessão de modelagem, foram utilizadas as poderosas ferramentas do pacote `pycomp`, permitindo assim uma rápida e rica análise dos modelos candidatos, desde o treinamento até a avaliação da performance e de diversos outros parâmetros relevantes para uma decisão mais assertiva sobre o melhor modelo para uma determinada tarefa.
#
# Ao longo das sessões 4.2 e 4.2, cada método do módulo `pycomp.ml.trainer` foi executado individualmente de modo a proporcionar uma análise específica sobre cada uma das frentes envolvidas. Em termos práticos, nem sempre é desejável separar a análise indivualmente para cada um dos métodos e gráficos disponíveis, mas sim realizar todas as análises de uma única vez.
#
# Pensando nisso, foi construído, dentro da classe `ClassificadorBinario`, dois métodos responsáveis por realizar todos os passos acima de forma consolidada. São eles: `training_flow()` e `visual_analysis()`. A grande diferença se dá pela necessidade de informar apenas alguns argumentos essenciais para que se possa realizar o treinamento, avaliação e geração de gráficos de análise. Os resultados podem ser salvos em diretórios específicos definidos pelo usuário.
#
# Na célula abaixo, vamos simular a execução destes dois métodos.

# %%
# Instanciando novo objeto
full_trainer = ClassificadorBinario()

# Realizando treinamento e avaliação dos modelos
full_trainer.training_flow(set_classifiers, X_train_prep, y_train, X_val_prep, y_val, 
                           features=MODEL_FEATURES, random_search=True)

# Gerando e salvando gráficos de análises visuais
full_trainer.visual_analysis(features=MODEL_FEATURES, model_shap='XGBClassifier')
# Out:
# DEBUG;2021-02-03 20:35:40;trainer.py;trainer;229;Treinando modelo DecisionTreeClassifier
# DEBUG;2021-02-03 20:35:40;trainer.py;trainer;249;Aplicando RandomizedSearchCV
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.0s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.2s finished
# DEBUG;2021-02-03 20:35:41;trainer.py;trainer;229;Treinando modelo RandomForestClassifier
# DEBUG;2021-02-03 20:35:41;trainer.py;trainer;249;Aplicando RandomizedSearchCV
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.5s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.6s finished
# DEBUG;2021-02-03 20:35:42;trainer.py;trainer;229;Treinando modelo LGBMClassifier
# DEBUG;2021-02-03 20:35:42;trainer.py;trainer;249;Aplicando RandomizedSearchCV
# ...

# %% [markdown]
# Após a execução dos métodos `training_flow()` e `visual_analysis()` acima especificados, tem-se uma série de outputs gerados que podem ser acessados futuramente para uma análise mais detalhada.

# %%
# !tree output/
# Out:
# output/
# ├── imgs
# │   ├── confusion_matrix.png
# │   ├── feature_importances.png
# │   ├── learning_curve.png
# │   ├── metrics_comparison.png
# │   ├── roc_curve.png
# │   ├── score_bins_percent.png
# │   ├── score_bins.png
# │   ├── score_distribution.png
# │   ├── shap_analysis_LGBMClassifier.png
# │   ├── shap_analysis_RandomForest.png
# │   └── shap_analysis_XGBClassifier.png
# ├── metrics
# │   ├── metrics.csv
# │   └── top_features.csv
# ├── models
# │   ├── decisiontrees.pkl
# │   ├── logisticregression.pkl
# │   ├── metrics.csv
# │   └── randomforest.pkl
# └── submission.csv
#
# 3 directories, 18 files

# %% [markdown]
# # Tunagem de Hyperparâmetros

# %% [markdown]
# Após uma longa jornada exploratória e de preparação na base de dados disponível para essa tarefa, temos em mãos insumos suficientes para decidir entre alguns modelos candidatos de modo a propor um aperfeiçoamento em suas performances através da tunagem de hiperparâmetros.
#
# Até o momento, os treinamentos foram realizados considerando uma configuração `default` em todos os algoritmos o que, de fato, não permite extrair todo o potencial do modelo. Nessa etapa, vamos separar alguns modelos candidatos que apresentaram performance razoável nessa etapa inicial ou que, de certa forma, podem apresentar uma proposta promissora após a tunagem de hiperparâmetros. Feita essa análise inicial, serão definidos dicionários de busca considerando hiperparâmetros específicos de cada um desses modelos pré selecionados. Ao final, será proposta uma análise completa, através do `RandomizedSearchCV` para encontrar a melhor combinação entre todas as combinações possíveis dos modelos candidatos.
#
# Dessa forma, vamos então rever os resultados obtidos pelos modelos candidatos.

# %%
# Métricas dos modelos
metrics = pd.read_csv('output/metrics/metrics.csv')
metrics
# Out:
#                          model          approach     acc  precision  recall  \
# 0       DecisionTreeClassifier  Treino 5 K-folds  0.7783     0.7220  0.7191
# 1       DecisionTreeClassifier             Teste  0.7143     0.7273  0.5333
# 2       RandomForestClassifier  Treino 5 K-folds  0.8283     0.7949  0.7305
# 3       RandomForestClassifier             Teste  0.7886     0.8065  0.6667
# 4               LGBMClassifier  Treino 5 K-folds  0.8254     0.7834  0.7528
# 5               LGBMClassifier             Teste  0.8057     0.8254  0.6933
# 6                XGBClassifier  Treino 5 K-folds  0.8384     0.8137  0.7491
# 7                XGBClassifier             Teste  0.8000     0.8125  0.6933
# 8           AdaBoostClassifier  Treino 5 K-folds  0.8111     0.7486  0.7637
# 9           AdaBoostClassifier             Teste  0.8000     0.7857  0.7333
# 10  GradientBoostingClassifier  Treino 5 K-folds  0.8283     0.8027  0.7267
# ...

# %% [markdown]
# Em um balanço geral, considerando a `acurácia` como objetivo de otimização, é possível considerar os modelos `RandomForest`, `LightGBM` e `XGBoost` como bons candidatos a tunagem de hiperparâmetros. Na prática, existe uma boa possibilidade de aperfeiçoamento de performance para estes modelos e, dessa forma, vamos construir alguns blocos capazes de nos auxiliar nessa busca e aprimoramento.
#
# O primeiro passo a ser realizado é a definição de dicionários contendo os hiperparâmetros de busca para cada um dos modelos selecionados. Com esse dicionário em mãos, iremos construir um novo `pipeline` contemplando:
#
# 1. Preparação dos dados com `prep_pipeline`;
# 2. Aplicação de feature selection com  `SeletorTopFeatures`;
# 3. Treinamento de modelo
#
# Assim, será possível utilizar os dicionários de hiperparâmetros para aplicar uma busca aleatória de modo a retornar a melhor combinação possível, seja em relação aos parâmetros de modelagem ou aos parâmetros de preparação da base (como a estratégia do imputer, a aplicação de transformação logaritma, o número de features a serem consideradas, entre outros).

# %% [markdown]
# ___

# %%
# Parâmetros de busca pro modelo RandomForest
forest_tunning_grid = {
    #'bootstrap': [True, False],
    'class_weight': [None, 'balanced'],
    #'criterion': ['gini', 'entropy'],
    'max_depth': [5, 6, 7, 8, 9, 10],
    #'max_features': [None, 'auto', 'sqrt', 'log2'],
    #'max_leaf_nodes': np.arange(3, 50, 2),
    #'min_impuriti_decrease': np.linspace(0, 1, 50),
    #'min_samples_leaf': np.arange(1, 100, 1),
    #'min_samples_split': np.arange(2, 100, 1),
    #'min_weight_fraction_leaf': np.linspace(0, 1, 50),
    'n_estimators': np.arange(50, 700, 50),
    #'oob_score': [True, False],
    'random_state': [42]
}

# Parâmetros de busca pro modelo LightGBM
lgbm_tunning_grid = {
    'boosting_type': ['gbdt'],
    'class_weight': [None, 'balanced'],
    #'colsample_bytree': np.linspace(.5, 1, 50),
    #'importance_type': ['split', 'gain'],
    'learning_rate': [0.003, 0.01, 0.03, 0.1, 0.3, 1, 3],
    'max_depth': np.arange(-1, 100, 2),
    #'min_child_samples': np.arange(10, 50, 1),
    #'min_child_weight': np.linspace(1e-4, 1, 100),
    'n_estimators': np.arange(300, 700, 50),
    'num_leaves': [5, 10, 15, 20],
    'objective': ['binary'],
    'random_state': [42],
    #'reg_alpha': np.linspace(.0, 1.0, 50)
}

# Parâmetros de busca pro modelo XGBoost
xgboost_tunning_grid = {
    #'base_score': np.linspace(0.3, 0.7, 50),
    'booster': ['gbtree'],
    'learning_rate': [0.003, 0.01, 0.03, 0.1, 0.3, 1, 3],
    'n_estimators': np.arange(300, 700, 50),
    'objective': ['binary:logistic'],
    'seed': [42],
    #'reg_alpha': np.linspace(.0, 1.0, 10),
    #'reg_lambda': np.linspace(.0, 1.0, 10)
}

# Parâmetros de busca pro modelo AdaBoost
adaboost_tunning_grid = {
    'base_estimator': [DecisionTreeClassifier(max_depth=7)],
    'n_estimators': np.arange(50, 700, 50),
    'learning_rate': [0.003, 0.01, 0.03, 0.1, 0.3, 1, 3],
    'algorithm': ['SAMME', 'SAMME.R'],
    'random_state': [42]
}

# Parâmetros de busca pro modelo GradientBoost
gradboost_tunning_grid = {
    'n_estimators': np.arange(50, 700, 50),
    'max_depth': [3, 6, 7, 8, 9, 10, 15],
    #'max_features': [None, 'auto', 'sqrt', 'log2'],
    #'max_leaf_nodes': np.arange(3, 50, 2),
    #'min_impuriti_decrease': np.linspace(0, 1, 50),
    #'min_samples_leaf': np.arange(1, 100, 1),
    #'min_samples_split': np.arange(2, 100, 1),
    #'min_weight_fraction_leaf': np.linspace(0, 1, 50),
    'random_state': [42]
}

# %%
# Importando bibliotecas adicionais
from pycomp.ml.transformers import SeletorTopFeatures
from pycomp.ml.trainer import clf_cv_performance
from sklearn.model_selection import RandomizedSearchCV

# Preparando variáveis para busca completa
tunning_models_keys = ['RandomForestClassifier', 'LGBMClassifier', 'XGBClassifier', 'AdaBoostClassifier',
                       'GradientBoostingClassifier']
tunning_param_grids = [forest_tunning_grid, lgbm_tunning_grid, xgboost_tunning_grid, adaboost_tunning_grid,
                       gradboost_tunning_grid]
tunned_pipelines = {}
general_metrics = pd.DataFrame({})
pipe_model_key = 'model'

# Preparando conjunto de dados para treinamento (treino + validação)
X = X_train.append(X_val)
y = np.concatenate((y_train, y_val))

# Iterando por cada modelo e grid
for model_name, param_grid in zip(tunning_models_keys, tunning_param_grids):
    
    # Retornando informações do modelo
    baseline_model = trainer._get_estimator(model_name)
    feature_importance = baseline_model.feature_importances_
    general_metrics = general_metrics.append(trainer._get_metrics(model_name))
    
    # Criando pipeline de preparação e predição
    tunning_pipeline = Pipeline([
        ('prep', prep_pipeline),
        ('selector', SeletorTopFeatures(feature_importance, k=len(MODEL_FEATURES))),
        (pipe_model_key, baseline_model)
    ])
    
    # Preparando grid do modelo para encaixar no grid do pipeline
    model_param_grid = {pipe_model_key + '__' + k: v for k, v in param_grid.items()}
    tunning_param_grid = {
        'prep__num__imputer__strategy': ['mean', 'median', 'most_frequent'],
        'prep__num__log_transformer__application': [True, False],
        'prep__num__scaler__scaler_type': [None, 'Standard', 'MinMax'],
        'selector__k': np.arange(5, len(MODEL_FEATURES) + 1, 2)
    } 
    tunning_param_grid.update(model_param_grid)
    
    # Aplicando busca com RandomizedSearchCV
    tunning_search = RandomizedSearchCV(tunning_pipeline, tunning_param_grid, scoring='accuracy', cv=5,
                                        n_jobs=-1, verbose=-1, random_state=42)
    tunning_search.fit(X, y)
    print(f'\nBest hyperparameters for {model_name} found by RandomizedSearch:\n')
    for k, v in tunning_search.best_params_.items():
        print(f'{k}: {v}')

    # Retornando objetos relacionados a melhor combinação encontrada
    final_pipeline = tunning_search.best_estimator_
    tunned_pipelines[model_name] = final_pipeline
    
    # Calculando métricas finais com o melhor pipeline
    final_metrics = clf_cv_performance(final_pipeline, X, y, model_name=model_name)
    model_metrics = trainer._get_metrics(model_name=model_name)
    metrics_cols = general_metrics.columns
    final_metrics = final_metrics.loc[:, metrics_cols]
    general_metrics = general_metrics.append(final_metrics)
    
# Verificando resultado final
general_metrics
# Out:
# DEBUG;2021-02-03 20:37:12;trainer.py;trainer;1438;Retornando estimator do modelo RandomForestClassifier já treinado
# DEBUG;2021-02-03 20:37:12;trainer.py;trainer;1459;Retornando as métricas do modelo RandomForestClassifier
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   14.2s finished
# Best hyperparameters for RandomForestClassifier found by RandomizedSearch:
#
# selector__k: 40
# prep__num__scaler__scaler_type: None
# prep__num__log_transformer__application: False
# prep__num__imputer__strategy: median
# model__random_state: 42
# model__n_estimators: 300
# model__max_depth: 6
# model__class_weight: None
# DEBUG;2021-02-03 20:37:40;trainer.py;trainer;1459;Retornando as métricas do modelo RandomForestClassifier
# DEBUG;2021-02-03 20:37:40;trainer.py;trainer;1438;Retornando estimator do modelo LGBMClassifier já treinado
# ...

# %% [markdown]
# Por fim, tendo em vista as melhores combinações obtidas pra cada um dos modelos e as metricas finais resultantes, é possível tomar uma decisão mais assertiva sobre o modelo final a ser considerado para a previsão de sobrevivência na base oficial de testes. Observando o dataset de métricas, percebe-se que, em praticamente todos os casos, houve um aumento na performance final dos modelos candidatos após a aplicação da busca pelos hiperparâmetros. Um outro ponto relevante é que, nesse caso, foi utilizado a base de treino por completo (sem a separação entre treino e validação).
#
# Como modelo final, vamos selecionar o `XGBClassifier` por conta da melhor acurácia obtida na validação cruzada. Futuramente, é possível considerar outros algoritmos mais robustos para verificar uma possível melhoria na performance.

# %%
# Retornando o pipeline final a ser utilizado
FINAL_MODEL = 'RandomForestClassifier'
final_pipeline = tunned_pipelines[FINAL_MODEL]

# %% [markdown]
# # Teste: Validação Final

# %% [markdown]
# Por fim, pode-se então realizar a leitura da base oficial de testes disponibilizada para validação final do modelo preditivo. O objetivo é simular a execução dos pipelines de pré-processamento de dados e consumo do modelo treinado. Adicionalmente, pode-se inclusive estudar a possibilidade de consolidar um pipeline único capaz de receber uma base de validação, executar os pipelines de prep e consumir o modelo final, gerando assim uma base contendo o score e outros parâmetros que possam ser inclusos e necessários na base de saída.

# %%
# Lendo base final
df_test = pd.read_csv(os.path.join(DATA_PATH, TEST_FILENAME))
print(f'Dimensões da base de teste: {df_test.shape}')
df_test.head()
# Out:
# Dimensões da base de teste: (418, 11)
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# Após a leitura da base oficial de testes, vamos importar a classe `ConsumoModelo` que, por sua vez, é responsável por receber as informações de uma base de entrada e enriquecê-la com os resultados de um modelo preditivo já treinado. Uma vez retornado o pipeline final de melhor combinação obtido com o modelo `XGBoost`, é possível fornecer esse objeto como parâmetro de entrada pra classe de consumo do modelo, abrindo assim a possibilidade de criação de um pipeline de predição definitivo a ser aplicado em bases de teste.

# %%
# Importando classe
from pycomp.ml.transformers import ConsumoModelo

# Criando objeto e construindo pipeline de predição de resultados
model_consumer = ConsumoModelo(model=final_pipeline, features=INITIAL_PRED_FEATURES)

prediction_pipeline = Pipeline([
    ('initial', initial_pred_pipeline),
    ('prediction', model_consumer)
])

# Executando pipeline
df_pred = prediction_pipeline.fit_transform(df_test)
df_pred.head()
# Out:
#   Pclass     Sex   Age  SibSp  Parch     Fare Embarked name_title  \
# 0      3    male  34.5      0      0   7.8292        Q        Mr.
# 1      3  female  47.0      1      0   7.0000        S       Mrs.
# 2      2    male  62.0      0      0   9.6875        Q        Mr.
# 3      3    male  27.0      0      0   8.6625        S        Mr.
# 4      3  female  22.0      1      1  12.2875        S       Mrs.
#
#   ticket_class cabin_class  name_length     age_cat fare_cat  family_size  \
# 0        OTHER         NaN           16       20_40      0_8            1
# 1        OTHER         NaN           32       40_60      0_8            2
# 2        OTHER         NaN           25  greater_60     8_15            1
# 3        OTHER         NaN           16       20_40     8_15            1
# 4        OTHER         NaN           44       20_40     8_15            3
#
#    y_pred  y_scores
# 0       0  0.102068
# 1       0  0.491587
# 2       0  0.152364
# 3       0  0.108055
# ...

# %% [markdown]
# Como última etapa, vamos preparar a base final de predição para submeter os resultados na competição do Kaggle.

# %%
# Preparando base de sumissão
df_sub = df_test.merge(df_pred, how='left', left_index=True, right_index=True)
df_sub = df_sub.loc[:, ['PassengerId', 'y_pred']]
df_sub.columns = ['PassengerId', 'Survived']
df_sub.to_csv('output/submission.csv', index=False)
df_sub.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
